# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %%
print(X.shape)
# Out:
# (5, 4)

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027204961e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.79856129989e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W2 max relative error: 3.440708e-09
# b2 max relative error: 3.865091e-11
# W1 max relative error: 3.561318e-09
# b1 max relative error: 1.555471e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.0171496079387

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302550
# iteration 200 / 1000: loss 2.297648
# iteration 300 / 1000: loss 2.259602
# iteration 400 / 1000: loss 2.204170
# iteration 500 / 1000: loss 2.118565
# iteration 600 / 1000: loss 2.051535
# iteration 700 / 1000: loss 1.988466
# iteration 800 / 1000: loss 2.006591
# iteration 900 / 1000: loss 1.951473
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 
best_val = -1

hidden_sizes = np.arange(100, 600, 100)
learning_rates = 1 / np.power(10,np.arange(4, 8))
regs = [0.1, 0.03, 0.01]
i = 0

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
for h in hidden_sizes:
    for lr in learning_rates:
        for r in regs:
            net = TwoLayerNet(input_size, h, num_classes)
            i += 1
            print("On model", i)
            # Train the network
            stats = net.train(X_train, y_train, X_val, y_val,
                        num_iters=1000, batch_size=200,
                        learning_rate=lr, learning_rate_decay=0.95,
                        reg=r, verbose=True)
            # Predict on the validation set
            val_acc = (net.predict(X_val) == y_val).mean()
            
            if val_acc > best_val:
                best_val = val_acc
                best_net = net
#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
print(best_val)
# Out:
# On model 1
# iteration 0 / 1000: loss 2.302881
# iteration 100 / 1000: loss 2.302008
# iteration 200 / 1000: loss 2.289206
# iteration 300 / 1000: loss 2.224119
# iteration 400 / 1000: loss 2.188830
# iteration 500 / 1000: loss 2.074779
# iteration 600 / 1000: loss 2.064193
# iteration 700 / 1000: loss 2.021709
# iteration 800 / 1000: loss 2.096587
# iteration 900 / 1000: loss 1.962392
# On model 2
# iteration 0 / 1000: loss 2.302657
# iteration 100 / 1000: loss 2.301895
# iteration 200 / 1000: loss 2.293174
# iteration 300 / 1000: loss 2.248624
# iteration 400 / 1000: loss 2.142771
# iteration 500 / 1000: loss 2.102810
# iteration 600 / 1000: loss 2.065700
# iteration 700 / 1000: loss 2.046255
# iteration 800 / 1000: loss 2.042234
# iteration 900 / 1000: loss 1.953903
# On model 3
# iteration 0 / 1000: loss 2.302602
# iteration 100 / 1000: loss 2.301649
# iteration 200 / 1000: loss 2.295331
# iteration 300 / 1000: loss 2.237294
# iteration 400 / 1000: loss 2.134159
# iteration 500 / 1000: loss 1.970657
# iteration 600 / 1000: loss 2.025379
# iteration 700 / 1000: loss 2.005225
# iteration 800 / 1000: loss 1.934139
# iteration 900 / 1000: loss 1.932882
# On model 4
# iteration 0 / 1000: loss 2.302874
# iteration 100 / 1000: loss 2.302823
# iteration 200 / 1000: loss 2.302735
# iteration 300 / 1000: loss 2.302728
# iteration 400 / 1000: loss 2.302677
# iteration 500 / 1000: loss 2.302540
# iteration 600 / 1000: loss 2.302545
# iteration 700 / 1000: loss 2.302395
# iteration 800 / 1000: loss 2.302083
# iteration 900 / 1000: loss 2.302091
# On model 5
# iteration 0 / 1000: loss 2.302685
# iteration 100 / 1000: loss 2.302614
# iteration 200 / 1000: loss 2.302575
# iteration 300 / 1000: loss 2.302569
# iteration 400 / 1000: loss 2.302448
# iteration 500 / 1000: loss 2.302354
# iteration 600 / 1000: loss 2.302281
# iteration 700 / 1000: loss 2.302104
# iteration 800 / 1000: loss 2.302051
# iteration 900 / 1000: loss 2.301904
# On model 6
# iteration 0 / 1000: loss 2.302636
# iteration 100 / 1000: loss 2.302588
# iteration 200 / 1000: loss 2.302508
# iteration 300 / 1000: loss 2.302457
# iteration 400 / 1000: loss 2.302363
# iteration 500 / 1000: loss 2.302302
# iteration 600 / 1000: loss 2.302288
# iteration 700 / 1000: loss 2.302154
# iteration 800 / 1000: loss 2.302206
# iteration 900 / 1000: loss 2.301929
# On model 7
# iteration 0 / 1000: loss 2.302893
# iteration 100 / 1000: loss 2.302902
# iteration 200 / 1000: loss 2.302854
# iteration 300 / 1000: loss 2.302875
# iteration 400 / 1000: loss 2.302847
# iteration 500 / 1000: loss 2.302885
# iteration 600 / 1000: loss 2.302858
# iteration 700 / 1000: loss 2.302889
# iteration 800 / 1000: loss 2.302854
# iteration 900 / 1000: loss 2.302880
# On model 8
# iteration 0 / 1000: loss 2.302722
# iteration 100 / 1000: loss 2.302697
# iteration 200 / 1000: loss 2.302717
# iteration 300 / 1000: loss 2.302698
# iteration 400 / 1000: loss 2.302664
# iteration 500 / 1000: loss 2.302688
# iteration 600 / 1000: loss 2.302662
# iteration 700 / 1000: loss 2.302683
# iteration 800 / 1000: loss 2.302664
# iteration 900 / 1000: loss 2.302666
# On model 9
# iteration 0 / 1000: loss 2.302605
# iteration 100 / 1000: loss 2.302620
# iteration 200 / 1000: loss 2.302594
# iteration 300 / 1000: loss 2.302603
# iteration 400 / 1000: loss 2.302622
# iteration 500 / 1000: loss 2.302618
# iteration 600 / 1000: loss 2.302596
# iteration 700 / 1000: loss 2.302599
# iteration 800 / 1000: loss 2.302578
# iteration 900 / 1000: loss 2.302602
# On model 10
# iteration 0 / 1000: loss 2.302914
# iteration 100 / 1000: loss 2.302891
# iteration 200 / 1000: loss 2.302895
# iteration 300 / 1000: loss 2.302935
# iteration 400 / 1000: loss 2.302895
# iteration 500 / 1000: loss 2.302884
# iteration 600 / 1000: loss 2.302932
# iteration 700 / 1000: loss 2.302883
# iteration 800 / 1000: loss 2.302914
# iteration 900 / 1000: loss 2.302903
# On model 11
# iteration 0 / 1000: loss 2.302660
# iteration 100 / 1000: loss 2.302717
# iteration 200 / 1000: loss 2.302679
# iteration 300 / 1000: loss 2.302677
# iteration 400 / 1000: loss 2.302674
# iteration 500 / 1000: loss 2.302686
# iteration 600 / 1000: loss 2.302672
# iteration 700 / 1000: loss 2.302682
# iteration 800 / 1000: loss 2.302687
# iteration 900 / 1000: loss 2.302697
# On model 12
# iteration 0 / 1000: loss 2.302600
# iteration 100 / 1000: loss 2.302636
# iteration 200 / 1000: loss 2.302622
# iteration 300 / 1000: loss 2.302582
# iteration 400 / 1000: loss 2.302591
# iteration 500 / 1000: loss 2.302592
# iteration 600 / 1000: loss 2.302597
# iteration 700 / 1000: loss 2.302575
# iteration 800 / 1000: loss 2.302607
# iteration 900 / 1000: loss 2.302632
# On model 13
# iteration 0 / 1000: loss 2.303233
# iteration 100 / 1000: loss 2.301445
# iteration 200 / 1000: loss 2.283489
# iteration 300 / 1000: loss 2.232726
# iteration 400 / 1000: loss 2.103951
# iteration 500 / 1000: loss 2.103190
# iteration 600 / 1000: loss 2.036474
# iteration 700 / 1000: loss 2.016940
# iteration 800 / 1000: loss 1.964171
# iteration 900 / 1000: loss 1.900041
# On model 14
# iteration 0 / 1000: loss 2.302783
# iteration 100 / 1000: loss 2.301154
# iteration 200 / 1000: loss 2.286356
# iteration 300 / 1000: loss 2.213856
# iteration 400 / 1000: loss 2.136149
# iteration 500 / 1000: loss 2.089504
# iteration 600 / 1000: loss 2.015749
# iteration 700 / 1000: loss 2.050699
# iteration 800 / 1000: loss 2.019435
# iteration 900 / 1000: loss 1.946744
# On model 15
# iteration 0 / 1000: loss 2.302637
# iteration 100 / 1000: loss 2.300749
# iteration 200 / 1000: loss 2.285370
# iteration 300 / 1000: loss 2.221398
# iteration 400 / 1000: loss 2.073285
# iteration 500 / 1000: loss 2.065011
# iteration 600 / 1000: loss 1.945629
# iteration 700 / 1000: loss 2.062445
# iteration 800 / 1000: loss 1.984887
# iteration 900 / 1000: loss 1.921108
# On model 16
# iteration 0 / 1000: loss 2.303192
# iteration 100 / 1000: loss 2.303082
# iteration 200 / 1000: loss 2.302937
# iteration 300 / 1000: loss 2.302880
# iteration 400 / 1000: loss 2.302677
# iteration 500 / 1000: loss 2.302660
# iteration 600 / 1000: loss 2.302559
# iteration 700 / 1000: loss 2.302111
# iteration 800 / 1000: loss 2.302147
# iteration 900 / 1000: loss 2.301735
# On model 17
# iteration 0 / 1000: loss 2.302797
# iteration 100 / 1000: loss 2.302711
# iteration 200 / 1000: loss 2.302673
# iteration 300 / 1000: loss 2.302524
# iteration 400 / 1000: loss 2.302461
# iteration 500 / 1000: loss 2.302376
# iteration 600 / 1000: loss 2.302159
# iteration 700 / 1000: loss 2.301947
# iteration 800 / 1000: loss 2.301766
# iteration 900 / 1000: loss 2.301555
# On model 18
# iteration 0 / 1000: loss 2.302622
# iteration 100 / 1000: loss 2.302569
# iteration 200 / 1000: loss 2.302476
# iteration 300 / 1000: loss 2.302300
# iteration 400 / 1000: loss 2.302264
# iteration 500 / 1000: loss 2.302185
# iteration 600 / 1000: loss 2.302085
# iteration 700 / 1000: loss 2.301888
# iteration 800 / 1000: loss 2.301536
# iteration 900 / 1000: loss 2.301425
# On model 19
# iteration 0 / 1000: loss 2.303220
# iteration 100 / 1000: loss 2.303184
# iteration 200 / 1000: loss 2.303175
# iteration 300 / 1000: loss 2.303153
# iteration 400 / 1000: loss 2.303193
# iteration 500 / 1000: loss 2.303191
# iteration 600 / 1000: loss 2.303170
# iteration 700 / 1000: loss 2.303183
# iteration 800 / 1000: loss 2.303109
# iteration 900 / 1000: loss 2.303160
# On model 20
# iteration 0 / 1000: loss 2.302801
# iteration 100 / 1000: loss 2.302783
# iteration 200 / 1000: loss 2.302787
# iteration 300 / 1000: loss 2.302777
# iteration 400 / 1000: loss 2.302761
# iteration 500 / 1000: loss 2.302730
# iteration 600 / 1000: loss 2.302799
# iteration 700 / 1000: loss 2.302754
# iteration 800 / 1000: loss 2.302736
# iteration 900 / 1000: loss 2.302707
# On model 21
# iteration 0 / 1000: loss 2.302699
# iteration 100 / 1000: loss 2.302658
# iteration 200 / 1000: loss 2.302648
# iteration 300 / 1000: loss 2.302657
# iteration 400 / 1000: loss 2.302638
# iteration 500 / 1000: loss 2.302620
# iteration 600 / 1000: loss 2.302661
# iteration 700 / 1000: loss 2.302633
# iteration 800 / 1000: loss 2.302629
# iteration 900 / 1000: loss 2.302662
# On model 22
# iteration 0 / 1000: loss 2.303185
# iteration 100 / 1000: loss 2.303165
# iteration 200 / 1000: loss 2.303165
# iteration 300 / 1000: loss 2.303162
# iteration 400 / 1000: loss 2.303066
# iteration 500 / 1000: loss 2.303187
# iteration 600 / 1000: loss 2.303167
# iteration 700 / 1000: loss 2.303138
# iteration 800 / 1000: loss 2.303167
# iteration 900 / 1000: loss 2.303129
# On model 23
# iteration 0 / 1000: loss 2.302830
# iteration 100 / 1000: loss 2.302788
# iteration 200 / 1000: loss 2.302781
# iteration 300 / 1000: loss 2.302808
# iteration 400 / 1000: loss 2.302814
# iteration 500 / 1000: loss 2.302828
# iteration 600 / 1000: loss 2.302773
# iteration 700 / 1000: loss 2.302801
# iteration 800 / 1000: loss 2.302841
# iteration 900 / 1000: loss 2.302740
# On model 24
# iteration 0 / 1000: loss 2.302603
# iteration 100 / 1000: loss 2.302644
# iteration 200 / 1000: loss 2.302656
# iteration 300 / 1000: loss 2.302652
# iteration 400 / 1000: loss 2.302685
# iteration 500 / 1000: loss 2.302637
# iteration 600 / 1000: loss 2.302604
# iteration 700 / 1000: loss 2.302674
# iteration 800 / 1000: loss 2.302644
# iteration 900 / 1000: loss 2.302651
# On model 25
# iteration 0 / 1000: loss 2.303524
# iteration 100 / 1000: loss 2.301005
# iteration 200 / 1000: loss 2.280485
# iteration 300 / 1000: loss 2.199348
# iteration 400 / 1000: loss 2.091670
# iteration 500 / 1000: loss 2.126806
# iteration 600 / 1000: loss 2.007532
# iteration 700 / 1000: loss 1.977969
# iteration 800 / 1000: loss 1.890659
# iteration 900 / 1000: loss 1.925007
# On model 26
# iteration 0 / 1000: loss 2.302850
# iteration 100 / 1000: loss 2.300218
# iteration 200 / 1000: loss 2.284578
# iteration 300 / 1000: loss 2.220562
# iteration 400 / 1000: loss 2.160881
# iteration 500 / 1000: loss 2.034809
# iteration 600 / 1000: loss 2.054987
# iteration 700 / 1000: loss 1.994066
# iteration 800 / 1000: loss 1.920139
# iteration 900 / 1000: loss 1.878485
# On model 27
# iteration 0 / 1000: loss 2.302752
# iteration 100 / 1000: loss 2.300539
# iteration 200 / 1000: loss 2.284299
# iteration 300 / 1000: loss 2.168405
# iteration 400 / 1000: loss 2.117236
# iteration 500 / 1000: loss 2.098295
# iteration 600 / 1000: loss 2.046736
# iteration 700 / 1000: loss 2.032527
# iteration 800 / 1000: loss 1.955165
# iteration 900 / 1000: loss 2.049838
# On model 28
# iteration 0 / 1000: loss 2.303533
# iteration 100 / 1000: loss 2.303404
# iteration 200 / 1000: loss 2.303226
# iteration 300 / 1000: loss 2.303057
# iteration 400 / 1000: loss 2.303009
# iteration 500 / 1000: loss 2.302690
# iteration 600 / 1000: loss 2.302635
# iteration 700 / 1000: loss 2.302441
# iteration 800 / 1000: loss 2.302291
# iteration 900 / 1000: loss 2.301835
# On model 29
# iteration 0 / 1000: loss 2.302890
# iteration 100 / 1000: loss 2.302736
# iteration 200 / 1000: loss 2.302640
# iteration 300 / 1000: loss 2.302404
# iteration 400 / 1000: loss 2.302275
# iteration 500 / 1000: loss 2.302062
# iteration 600 / 1000: loss 2.302081
# iteration 700 / 1000: loss 2.301958
# iteration 800 / 1000: loss 2.301527
# iteration 900 / 1000: loss 2.301178
# On model 30
# iteration 0 / 1000: loss 2.302684
# iteration 100 / 1000: loss 2.302554
# iteration 200 / 1000: loss 2.302442
# iteration 300 / 1000: loss 2.302206
# iteration 400 / 1000: loss 2.302102
# iteration 500 / 1000: loss 2.301843
# iteration 600 / 1000: loss 2.301637
# iteration 700 / 1000: loss 2.301543
# iteration 800 / 1000: loss 2.300941
# iteration 900 / 1000: loss 2.300784
# On model 31
# iteration 0 / 1000: loss 2.303545
# iteration 100 / 1000: loss 2.303449
# iteration 200 / 1000: loss 2.303381
# iteration 300 / 1000: loss 2.303392
# iteration 400 / 1000: loss 2.303504
# iteration 500 / 1000: loss 2.303420
# iteration 600 / 1000: loss 2.303403
# iteration 700 / 1000: loss 2.303389
# iteration 800 / 1000: loss 2.303409
# iteration 900 / 1000: loss 2.303381
# On model 32
# iteration 0 / 1000: loss 2.302835
# iteration 100 / 1000: loss 2.302836
# iteration 200 / 1000: loss 2.302780
# iteration 300 / 1000: loss 2.302843
# iteration 400 / 1000: loss 2.302823
# iteration 500 / 1000: loss 2.302786
# iteration 600 / 1000: loss 2.302794
# iteration 700 / 1000: loss 2.302759
# iteration 800 / 1000: loss 2.302734
# iteration 900 / 1000: loss 2.302767
# On model 33
# iteration 0 / 1000: loss 2.302719
# iteration 100 / 1000: loss 2.302750
# iteration 200 / 1000: loss 2.302663
# iteration 300 / 1000: loss 2.302617
# iteration 400 / 1000: loss 2.302702
# iteration 500 / 1000: loss 2.302643
# iteration 600 / 1000: loss 2.302663
# iteration 700 / 1000: loss 2.302649
# iteration 800 / 1000: loss 2.302618
# iteration 900 / 1000: loss 2.302620
# On model 34
# iteration 0 / 1000: loss 2.303497
# iteration 100 / 1000: loss 2.303540
# iteration 200 / 1000: loss 2.303523
# iteration 300 / 1000: loss 2.303531
# iteration 400 / 1000: loss 2.303542
# iteration 500 / 1000: loss 2.303534
# iteration 600 / 1000: loss 2.303520
# iteration 700 / 1000: loss 2.303473
# iteration 800 / 1000: loss 2.303468
# iteration 900 / 1000: loss 2.303508
# On model 35
# iteration 0 / 1000: loss 2.302864
# iteration 100 / 1000: loss 2.302903
# iteration 200 / 1000: loss 2.302887
# iteration 300 / 1000: loss 2.302910
# iteration 400 / 1000: loss 2.302908
# iteration 500 / 1000: loss 2.302871
# iteration 600 / 1000: loss 2.302875
# iteration 700 / 1000: loss 2.302886
# iteration 800 / 1000: loss 2.302847
# iteration 900 / 1000: loss 2.302872
# On model 36
# iteration 0 / 1000: loss 2.302691
# iteration 100 / 1000: loss 2.302698
# iteration 200 / 1000: loss 2.302705
# iteration 300 / 1000: loss 2.302692
# iteration 400 / 1000: loss 2.302673
# iteration 500 / 1000: loss 2.302698
# iteration 600 / 1000: loss 2.302657
# iteration 700 / 1000: loss 2.302678
# iteration 800 / 1000: loss 2.302686
# iteration 900 / 1000: loss 2.302646
# On model 37
# iteration 0 / 1000: loss 2.303767
# iteration 100 / 1000: loss 2.300181
# iteration 200 / 1000: loss 2.267714
# iteration 300 / 1000: loss 2.199201
# iteration 400 / 1000: loss 2.100571
# iteration 500 / 1000: loss 2.013954
# iteration 600 / 1000: loss 2.011999
# iteration 700 / 1000: loss 2.040550
# iteration 800 / 1000: loss 2.018787
# iteration 900 / 1000: loss 1.926510
# On model 38
# iteration 0 / 1000: loss 2.302897
# iteration 100 / 1000: loss 2.298550
# iteration 200 / 1000: loss 2.266399
# iteration 300 / 1000: loss 2.160585
# iteration 400 / 1000: loss 2.105845
# iteration 500 / 1000: loss 2.049621
# iteration 600 / 1000: loss 2.052371
# iteration 700 / 1000: loss 1.970603
# iteration 800 / 1000: loss 2.074767
# iteration 900 / 1000: loss 1.903836
# On model 39
# iteration 0 / 1000: loss 2.302688
# iteration 100 / 1000: loss 2.299451
# iteration 200 / 1000: loss 2.280335
# iteration 300 / 1000: loss 2.197560
# iteration 400 / 1000: loss 2.121011
# iteration 500 / 1000: loss 2.068216
# iteration 600 / 1000: loss 1.946963
# iteration 700 / 1000: loss 1.932248
# iteration 800 / 1000: loss 2.010542
# iteration 900 / 1000: loss 1.911550
# On model 40
# iteration 0 / 1000: loss 2.303837
# iteration 100 / 1000: loss 2.303698
# iteration 200 / 1000: loss 2.303492
# iteration 300 / 1000: loss 2.303169
# iteration 400 / 1000: loss 2.303083
# iteration 500 / 1000: loss 2.302973
# iteration 600 / 1000: loss 2.302571
# iteration 700 / 1000: loss 2.302244
# iteration 800 / 1000: loss 2.302331
# iteration 900 / 1000: loss 2.302053
# On model 41
# iteration 0 / 1000: loss 2.302938
# iteration 100 / 1000: loss 2.302727
# iteration 200 / 1000: loss 2.302540
# iteration 300 / 1000: loss 2.302244
# iteration 400 / 1000: loss 2.301795
# iteration 500 / 1000: loss 2.301958
# iteration 600 / 1000: loss 2.301359
# iteration 700 / 1000: loss 2.301881
# iteration 800 / 1000: loss 2.301148
# iteration 900 / 1000: loss 2.300260
# On model 42
# iteration 0 / 1000: loss 2.302689
# iteration 100 / 1000: loss 2.302506
# iteration 200 / 1000: loss 2.302227
# iteration 300 / 1000: loss 2.302089
# iteration 400 / 1000: loss 2.301881
# iteration 500 / 1000: loss 2.301359
# iteration 600 / 1000: loss 2.301313
# iteration 700 / 1000: loss 2.301062
# iteration 800 / 1000: loss 2.300265
# iteration 900 / 1000: loss 2.300818
# On model 43
# iteration 0 / 1000: loss 2.303877
# iteration 100 / 1000: loss 2.303821
# iteration 200 / 1000: loss 2.303811
# iteration 300 / 1000: loss 2.303781
# iteration 400 / 1000: loss 2.303754
# iteration 500 / 1000: loss 2.303729
# iteration 600 / 1000: loss 2.303757
# iteration 700 / 1000: loss 2.303719
# iteration 800 / 1000: loss 2.303682
# iteration 900 / 1000: loss 2.303642
# On model 44
# iteration 0 / 1000: loss 2.302982
# iteration 100 / 1000: loss 2.302953
# iteration 200 / 1000: loss 2.302995
# iteration 300 / 1000: loss 2.302936
# iteration 400 / 1000: loss 2.302896
# iteration 500 / 1000: loss 2.302974
# iteration 600 / 1000: loss 2.302952
# iteration 700 / 1000: loss 2.302852
# iteration 800 / 1000: loss 2.302930
# iteration 900 / 1000: loss 2.302830
# On model 45
# iteration 0 / 1000: loss 2.302701
# iteration 100 / 1000: loss 2.302617
# iteration 200 / 1000: loss 2.302651
# iteration 300 / 1000: loss 2.302647
# iteration 400 / 1000: loss 2.302632
# iteration 500 / 1000: loss 2.302629
# iteration 600 / 1000: loss 2.302570
# iteration 700 / 1000: loss 2.302610
# iteration 800 / 1000: loss 2.302580
# iteration 900 / 1000: loss 2.302513
# On model 46
# iteration 0 / 1000: loss 2.303756
# iteration 100 / 1000: loss 2.303807
# iteration 200 / 1000: loss 2.303779
# iteration 300 / 1000: loss 2.303734
# iteration 400 / 1000: loss 2.303783
# iteration 500 / 1000: loss 2.303783
# iteration 600 / 1000: loss 2.303812
# iteration 700 / 1000: loss 2.303791
# iteration 800 / 1000: loss 2.303789
# iteration 900 / 1000: loss 2.303779
# On model 47
# iteration 0 / 1000: loss 2.302870
# iteration 100 / 1000: loss 2.302886
# iteration 200 / 1000: loss 2.302906
# iteration 300 / 1000: loss 2.302859
# iteration 400 / 1000: loss 2.302848
# iteration 500 / 1000: loss 2.302851
# iteration 600 / 1000: loss 2.302858
# iteration 700 / 1000: loss 2.302844
# iteration 800 / 1000: loss 2.302884
# iteration 900 / 1000: loss 2.302904
# On model 48
# iteration 0 / 1000: loss 2.302717
# iteration 100 / 1000: loss 2.302735
# iteration 200 / 1000: loss 2.302700
# iteration 300 / 1000: loss 2.302701
# iteration 400 / 1000: loss 2.302734
# iteration 500 / 1000: loss 2.302678
# iteration 600 / 1000: loss 2.302711
# iteration 700 / 1000: loss 2.302681
# iteration 800 / 1000: loss 2.302725
# iteration 900 / 1000: loss 2.302684
# On model 49
# iteration 0 / 1000: loss 2.304166
# iteration 100 / 1000: loss 2.299467
# iteration 200 / 1000: loss 2.283772
# iteration 300 / 1000: loss 2.205397
# iteration 400 / 1000: loss 2.132888
# iteration 500 / 1000: loss 2.078182
# iteration 600 / 1000: loss 1.965339
# iteration 700 / 1000: loss 1.981889
# iteration 800 / 1000: loss 2.004690
# iteration 900 / 1000: loss 1.914361
# On model 50
# iteration 0 / 1000: loss 2.303011
# iteration 100 / 1000: loss 2.298294
# iteration 200 / 1000: loss 2.263702
# iteration 300 / 1000: loss 2.150821
# iteration 400 / 1000: loss 2.122587
# iteration 500 / 1000: loss 2.027026
# iteration 600 / 1000: loss 1.994859
# iteration 700 / 1000: loss 2.008581
# iteration 800 / 1000: loss 1.908625
# iteration 900 / 1000: loss 1.882402
# On model 51
# iteration 0 / 1000: loss 2.302795
# iteration 100 / 1000: loss 2.298939
# iteration 200 / 1000: loss 2.263527
# iteration 300 / 1000: loss 2.197512
# iteration 400 / 1000: loss 2.091842
# iteration 500 / 1000: loss 2.067631
# iteration 600 / 1000: loss 1.985040
# iteration 700 / 1000: loss 1.915677
# iteration 800 / 1000: loss 1.952338
# iteration 900 / 1000: loss 1.888778
# On model 52
# iteration 0 / 1000: loss 2.304155
# iteration 100 / 1000: loss 2.303975
# iteration 200 / 1000: loss 2.303746
# iteration 300 / 1000: loss 2.303507
# iteration 400 / 1000: loss 2.303202
# iteration 500 / 1000: loss 2.303053
# iteration 600 / 1000: loss 2.302880
# iteration 700 / 1000: loss 2.302287
# iteration 800 / 1000: loss 2.301366
# iteration 900 / 1000: loss 2.300635
# On model 53
# iteration 0 / 1000: loss 2.303071
# iteration 100 / 1000: loss 2.302778
# iteration 200 / 1000: loss 2.302587
# iteration 300 / 1000: loss 2.302421
# iteration 400 / 1000: loss 2.301868
# iteration 500 / 1000: loss 2.301959
# iteration 600 / 1000: loss 2.301368
# iteration 700 / 1000: loss 2.301244
# iteration 800 / 1000: loss 2.300203
# iteration 900 / 1000: loss 2.300386
# On model 54
# iteration 0 / 1000: loss 2.302708
# iteration 100 / 1000: loss 2.302513
# iteration 200 / 1000: loss 2.302286
# iteration 300 / 1000: loss 2.302142
# iteration 400 / 1000: loss 2.301805
# iteration 500 / 1000: loss 2.301628
# iteration 600 / 1000: loss 2.300955
# iteration 700 / 1000: loss 2.300406
# iteration 800 / 1000: loss 2.299979
# iteration 900 / 1000: loss 2.299758
# On model 55
# iteration 0 / 1000: loss 2.304165
# iteration 100 / 1000: loss 2.304156
# iteration 200 / 1000: loss 2.304152
# iteration 300 / 1000: loss 2.304091
# iteration 400 / 1000: loss 2.304067
# iteration 500 / 1000: loss 2.304068
# iteration 600 / 1000: loss 2.303999
# iteration 700 / 1000: loss 2.304044
# iteration 800 / 1000: loss 2.303971
# iteration 900 / 1000: loss 2.303935
# On model 56
# iteration 0 / 1000: loss 2.303032
# iteration 100 / 1000: loss 2.302994
# iteration 200 / 1000: loss 2.302898
# iteration 300 / 1000: loss 2.302910
# iteration 400 / 1000: loss 2.302924
# iteration 500 / 1000: loss 2.302923
# iteration 600 / 1000: loss 2.302846
# iteration 700 / 1000: loss 2.302834
# iteration 800 / 1000: loss 2.302831
# iteration 900 / 1000: loss 2.302779
# On model 57
# iteration 0 / 1000: loss 2.302695
# iteration 100 / 1000: loss 2.302677
# iteration 200 / 1000: loss 2.302653
# iteration 300 / 1000: loss 2.302642
# iteration 400 / 1000: loss 2.302585
# iteration 500 / 1000: loss 2.302557
# iteration 600 / 1000: loss 2.302639
# iteration 700 / 1000: loss 2.302556
# iteration 800 / 1000: loss 2.302479
# iteration 900 / 1000: loss 2.302547
# On model 58
# iteration 0 / 1000: loss 2.304137
# iteration 100 / 1000: loss 2.304120
# iteration 200 / 1000: loss 2.304129
# iteration 300 / 1000: loss 2.304097
# iteration 400 / 1000: loss 2.304091
# iteration 500 / 1000: loss 2.304136
# iteration 600 / 1000: loss 2.304123
# iteration 700 / 1000: loss 2.304154
# iteration 800 / 1000: loss 2.304116
# iteration 900 / 1000: loss 2.304082
# On model 59
# iteration 0 / 1000: loss 2.303065
# iteration 100 / 1000: loss 2.302992
# iteration 200 / 1000: loss 2.303034
# iteration 300 / 1000: loss 2.302963
# iteration 400 / 1000: loss 2.303007
# iteration 500 / 1000: loss 2.303041
# iteration 600 / 1000: loss 2.302949
# iteration 700 / 1000: loss 2.303053
# iteration 800 / 1000: loss 2.302992
# iteration 900 / 1000: loss 2.303059
# On model 60
# iteration 0 / 1000: loss 2.302720
# iteration 100 / 1000: loss 2.302711
# iteration 200 / 1000: loss 2.302761
# iteration 300 / 1000: loss 2.302712
# iteration 400 / 1000: loss 2.302731
# iteration 500 / 1000: loss 2.302707
# iteration 600 / 1000: loss 2.302743
# iteration 700 / 1000: loss 2.302715
# iteration 800 / 1000: loss 2.302782
# iteration 900 / 1000: loss 2.302686
# 0.32

# %%
# visualize the weights of the best network
show_net_weights(best_net)
print(best_val) #fuck this
# Out:
# 0.324

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
